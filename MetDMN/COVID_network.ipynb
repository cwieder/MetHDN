# %% [markdown]
# # COVID metabolite-metabolite network

# %%
from COVID_study_processing import MTBLSDataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from networkx.algorithms import bipartite
import libchebipy

# %%
s2014 = MTBLSDataset(
    file_path = 'Studies/MTBLS2014', 
    id = 'MTBLS2014', 
    node_name = 'MTBLS2014', 
    md_group = 'Factor Value[Disease]', 
    md_filter = ['Healthy', 'Patient (+) SARS-CoV-2'])
# Out:
#                 Sample Name   Factor Value[Disease]
# 0  03JUN2020_COV_AAA_PL_021                 Healthy
# 1  03JUN2020_COV_AAA_PL_024                 Healthy
# 2  03JUN2020_COV_AAA_PL_029  Patient (+) SARS-CoV-2
# 3  03JUN2020_COV_AAA_PL_032  Patient (+) SARS-CoV-2
# 4  03JUN2020_COV_AAA_PL_035  Patient (+) SARS-CoV-2
# Missingness: 0.00%
# Number of differentially abundant metabolites: 11

# %%
s014.pval_df
# Out:
#                   P-value   FDR_P-value
# CHEBI:35621  9.539117e-01  9.539117e-01
# CHEBI:27389  3.528701e-01  5.469487e-01
# CHEBI:16865  7.349991e-01  8.167683e-01
# CHEBI:16449  4.149123e-01  6.124896e-01
# CHEBI:37024  1.049832e-01  2.503445e-01
# CHEBI:29016  3.165494e-01  5.164754e-01
# CHEBI:22653  1.720942e-01  3.556613e-01
# CHEBI:22660  5.428203e-07  8.413715e-06
# CHEBI:18211  1.300944e-01  2.880662e-01
# CHEBI:17376  1.191318e-02  3.357352e-02
# CHEBI:16000  5.726665e-04  2.219083e-03
# CHEBI:18237  2.854421e-09  8.848706e-08
# CHEBI:28300  8.519665e-03  2.934551e-02
# CHEBI:15428  8.217794e-01  8.784538e-01
# CHEBI:27570  4.397323e-06  4.543900e-05
# CHEBI:24898  9.270377e-01  9.539117e-01
# CHEBI:25017  6.970883e-01  8.167683e-01
# CHEBI:25094  5.427183e-01  7.314899e-01
# CHEBI:16811  7.377262e-01  8.167683e-01
# CHEBI:18257  1.979768e-01  3.626751e-01
# CHEBI:28044  4.044036e-04  1.790930e-03
# CHEBI:26271  5.754074e-01  7.354634e-01
# CHEBI:15611  2.608748e-01  4.492844e-01
# CHEBI:17822  5.931156e-01  7.354634e-01
# CHEBI:15891  3.740084e-05  2.318852e-04
# CHEBI:26986  4.101575e-02  1.059574e-01
# CHEBI:27897  5.166905e-05  2.669568e-04
# CHEBI:18186  1.988863e-01  3.626751e-01
# CHEBI:27266  5.350623e-01  7.314899e-01
# CHEBI:16958  1.131892e-02  3.357352e-02
# CHEBI:28683  1.831322e-05  1.419274e-04

# %%
s6844 = MTBLSDataset(
    file_path = 'Studies/MTBLS6844', 
    id = 'MTBLS6844', 
    node_name = 'MTBLS6844', 
    md_group = 'Factor Value[Disease]', 
    md_filter = ['Severe', 'Mild'],
    maf_sheet=0)
# Out:
#   Sample Name Factor Value[Disease]
# 0       Blank                   NaN
# 1         PBS                   NaN
# 2  Calibrants                   NaN
# 3          QC                   NaN
# 4       MILD1                  Mild
# Missingness: 0.00%
# Number of differentially abundant metabolites: 3

# %%
# s718 = MTBLSDataset(
#     file_path = 'Studies/MTBLS718', 
#     id = 'MTBLS718', 
#     node_name = 'MTBLS718', 
#     md_group = 'Factor Value[Condition]', 
#     md_filter = ['COVID-19', 'Healthy Control'],
#     maf_sheet=2)

# %%
s1866 = MTBLSDataset(
    file_path = 'Studies/MTBLS1866', 
    id = 'MTBLS1866', 
    node_name = 'MTBLS1866', 
    md_group = 'Factor Value[Medical case]', 
    md_filter = ['HEALTHY', 'COVID-19'])
# Out:
#   Sample Name Factor Value[Medical case]
# 0           1                   COVID-19
# 1          41                   COVID-19
# 2         101                   COVID-19
# 3          62                   COVID-19
# 4         104                   COVID-19
# Missingness: 0.00%
# Number of differentially abundant metabolites: 115
# c:\Users\cw2019\.conda\envs\py12\Lib\site-packages\scipy\stats\_axis_nan_policy.py:563: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
s2224 = MTBLSDataset(
    file_path = 'Studies/MTBLS2224', 
    id = 'MTBLS2224', 
    node_name = 'MTBLS2224', 
    md_group = 'Factor Value[COVID Infection]', 
    md_filter = ['Positive', 'Negative'])
# Out:
#   Sample Name Factor Value[COVID Infection]
# 0        QC-3                           NaN
# 1        QC-4                           NaN
# 2        QC-5                           NaN
# 3        QC-6                           NaN
# 4        QC-7                           NaN
# Missingness: 0.00%
# Number of differentially abundant metabolites: 220

# %%
s2336 = MTBLSDataset(
    file_path = 'Studies/MTBLS2336', 
    id = 'MTBLS2336', 
    node_name = 'MTBLS2336', 
    md_group = 'Factor Value[Disease]', 
    md_filter = ['COVID-19', 'Healthy (control)'])
# Out:
#      Sample Name Factor Value[Disease]
# 0  COVID_ANN_001              COVID-19
# 1  COVID_ANN_002              COVID-19
# 2  COVID_ANN_003              COVID-19
# 3  COVID_ANN_004              COVID-19
# 4  COVID_ANN_005              COVID-19
# Missingness: 0.00%
# Number of differentially abundant metabolites: 11

# %%
s2542 = MTBLSDataset(
    file_path = 'Studies/MTBLS2542', 
    id = 'MTBLS2542', 
    node_name = 'MTBLS2542', 
    md_group = 'Factor Value[Disease severity]', 
    md_filter = ['Asymptomatic', 'severe'],
    maf_sheet=2)
# Out:
#               Sample Name Factor Value[Disease severity]
# 0  20P02820001_BEHC18_NEG                           Mild
# 1  20P02820001_BEHC18_POS                           Mild
# 2  20P02820002_BEHC18_NEG                           Mild
# 3  20P02820002_BEHC18_POS                           Mild
# 4  20P02820006_BEHC18_NEG                          Death
# Missingness: 0.00%
# Number of differentially abundant metabolites: 107

# %%
s2291 = MTBLSDataset(
    file_path = 'Studies/MTBLS2291', 
    id = 'MTBLS2291', 
    node_name = 'MTBLS2291', 
    md_group = 'Factor Value[Disease severity]', 
    md_filter = ['Negative COVID-19', 'Severe COVID-19'])
# Out:
#           Sample Name Factor Value[Disease severity]
# 0  CovidMild_P274_P_2            Non-severe COVID-19
# 1  CovidMild_P274_P_3            Non-severe COVID-19
# 2  CovidMild_P274_P_4            Non-severe COVID-19
# 3  CovidMild_P275_P_2            Non-severe COVID-19
# 4  CovidMild_P275_P_3            Non-severe COVID-19
# Missingness: 17.35%
# Number of differentially abundant metabolites: 50

# %%
s2291.plot_qc()
# Out:
# 0

# %% [markdown]
# ## Differential metabolites per study

# %%
studies = [s2014, s6844, s1866, s2224, s2336, s2542, s2291]

# %%
DA_res = pd.DataFrame(
    zip([len(i.DA_metabolites) for i in studies], [len(i.processed_data.columns)-1 for i in studies]),
    index=[i.node_name for i in studies],
    columns=['DA_count', 'ChEBI_count']
)

# %%
sns.set_style('ticks')
sns.barplot(
    data=DA_res.melt(ignore_index=False).reset_index(),
    x='index',
    y='value',
    hue='variable'
)
plt.ylabel('Number of differentially abundant metabolites')
plt.xlabel('Study ID')
plt.title('Differential metabolites per COVID study')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bipartite graph

# %%
def get_bipartite(studies):
    B = nx.Graph()
    # Add nodes with the node attribute "bipartite"-

    B.add_nodes_from([i.node_name for i in studies], bipartite=0)
    B.add_nodes_from(sum([i.DA_metabolites for i in studies], []), bipartite=1)
    # Add edges only between nodes of opposite node sets
    B.add_edges_from(sum([i.connection for i in studies], []))
    bottom_nodes, top_nodes = bipartite.sets(B)
    nx.is_connected(B)
    return B, bottom_nodes, top_nodes

# %%
covid_bpt, covid_bottom_nodes, covid_top_nodes = get_bipartite([s2014, s1866, s2224, s2336, s2542, s2291])

# %%
plt.figure(3,figsize=(8,16)) 
nx.draw_networkx(
    covid_bpt,
    pos = nx.drawing.layout.bipartite_layout(covid_bpt, covid_bottom_nodes),
    font_size=6,
    width = 0.3,
    with_labels=True,
    node_size=10,
    ) # Or whatever other display options you like

plt.show()

# %%
# force directed layout
pos = nx.drawing.layout.kamada_kawai_layout(covid_bpt)
color_map = []
labels = {}
for node in covid_bpt:
    if node in covid_bottom_nodes:
        print(node)
        color_map.append('red')
        labels[node] = node
    else: 
        color_map.append('blue')    
        # labels[node] = ''  


plt.figure(3,figsize=(10 ,10)) 
nx.draw_networkx(
    covid_bpt,
    pos = pos,
    font_size=6,
    width = 0.3,
    with_labels=False,
    node_size=10,
    node_color=color_map
    ) # Or whatever other display options you like
nx.draw_networkx_labels(covid_bpt, pos, labels,
                        bbox = dict(facecolor = "red", alpha=0.5, edgecolor='black', boxstyle='round,pad=0.3'),
                        font_size=8,
                        font_color='black')

plt.show()
# Out:
# MTBLS2014
# MTBLS1866
# MTBLS2224
# MTBLS2336
# MTBLS2542
# MTBLS2291

# %%
biadj_mat = nx.bipartite.biadjacency_matrix(covid_bpt, row_order=covid_bottom_nodes, column_order=covid_top_nodes).toarray()

# %%
sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(biadj_mat, cmap='viridis', cbar=False)
ax.set_yticklabels(covid_bottom_nodes, rotation=0)
ax.set_title('Biadjacency matrix of differential metabolites')
plt.show()

# %%
# create adjacency matrix based on the number of shared metabolites
# this can be done by multiplying the biadjacency matrix by its transpose
adj_mat = pd.DataFrame(biadj_mat @ biadj_mat.T, index=list(covid_bottom_nodes), columns=list(covid_bottom_nodes))

# fig, ax = plt.subplots(figsize=(7, 5))
sns.set(style='white')
sns.clustermap(
    adj_mat, 
    cmap='Blues', 
    square=True, 
    annot=True, 
    # cbar=False, 
    fmt='d', 
    linewidths=0.5, 
    linecolor='black' )
# ax.set_yticklabels(bottom_nodes, rotation=0)
# ax.set_xticklabels(bottom_nodes, rotation=90)
ax.set_title('Similarity matrix of differential metabolites')
# plt.tight_layout()
plt.show()
# Out:
# c:\Users\cw2019\.conda\envs\py12\Lib\site-packages\seaborn\matrix.py:1124: UserWarning: ``square=True`` ignored in clustermap
#   warnings.warn(msg)

# %% [markdown]
# ## Disease-metabolite network

# %%
# create adjacency matrix based on the number of shared metabolites
# this can be done by multiplying the biadjacency matrix by its transpose
adj_mat_dmn = pd.DataFrame(biadj_mat.T @ biadj_mat, index=list(covid_top_nodes), columns=list(covid_top_nodes))

# %%
adj_mat_dmn
# Out:
#               CHEBI:16015  CHEBI:75790  CHEBI:17697  CHEBI:36999  \
# CHEBI:16015             1            0            1            0
# CHEBI:75790             0            1            0            1
# CHEBI:17697             1            0            1            0
# CHEBI:36999             0            1            0            1
# CHEBI:166454            0            1            0            1
# ...                   ...          ...          ...          ...
# CHEBI:187920            1            0            1            0
# CHEBI:167762            0            1            0            1
# CHEBI:53487             0            1            0            1
# CHEBI:28161             0            0            0            0
# CHEBI:183272            0            0            0            0
#
#               CHEBI:166454  CHEBI:17482  CHEBI:87625  CHEBI:167810  \
# CHEBI:16015              0            1            0             0
# CHEBI:75790              1            0            0             1
# CHEBI:17697              0            1            0             0
# CHEBI:36999              1            0            0             1
# CHEBI:166454             1            0            0             1
# ...                    ...          ...          ...           ...
# CHEBI:187920             0            1            0             0
# CHEBI:167762             1            0            0             1
# CHEBI:53487              1            0            0             1
# CHEBI:28161              0            0            1             0
# CHEBI:183272             0            0            1             0
#
#               CHEBI:17748  CHEBI:17925  ...  CHEBI:16325  CHEBI:87393  \
# CHEBI:16015             1            1  ...            1            1
# CHEBI:75790             0            0  ...            0            0
# CHEBI:17697             1            1  ...            1            1
# CHEBI:36999             0            0  ...            0            0
# CHEBI:166454            0            0  ...            0            0
# ...                   ...          ...  ...          ...          ...
# CHEBI:187920            1            1  ...            1            1
# CHEBI:167762            0            0  ...            0            0
# CHEBI:53487             0            0  ...            0            0
# CHEBI:28161             0            0  ...            0            0
# CHEBI:183272            0            0  ...            0            0
#
#               CHEBI:15702  CHEBI:78668  CHEBI:17634  CHEBI:187920  \
# CHEBI:16015             1            0            0             1
# CHEBI:75790             0            1            0             0
# CHEBI:17697             1            0            0             1
# CHEBI:36999             0            1            0             0
# CHEBI:166454            0            1            0             0
# ...                   ...          ...          ...           ...
# CHEBI:187920            1            0            0             1
# CHEBI:167762            0            1            0             0
# CHEBI:53487             0            1            0             0
# CHEBI:28161             0            0            1             0
# CHEBI:183272            0            0            1             0
#
#               CHEBI:167762  CHEBI:53487  CHEBI:28161  CHEBI:183272
# CHEBI:16015              0            0            0             0
# CHEBI:75790              1            1            0             0
# CHEBI:17697              0            0            0             0
# CHEBI:36999              1            1            0             0
# CHEBI:166454             1            1            0             0
# ...                    ...          ...          ...           ...
# CHEBI:187920             0            0            0             0
# CHEBI:167762             1            1            0             0
# CHEBI:53487              1            1            0             0
# CHEBI:28161              0            0            1             1
# CHEBI:183272             0            0            1             1
#
# [454 rows x 454 columns]

# %%
# make pandas edgelist
edgelist_dmn = adj_mat_dmn.stack().reset_index()
edgelist_dmn.columns = ['source', 'target', 'weight']
edgelist_dmn = edgelist_dmn[edgelist_dmn['weight'] > 1]

# %%
edgelist_dmn.sort_values('weight', ascending=False)
# Out:
#               source        target  weight                   Name       Mass
# 97370    CHEBI:32816   CHEBI:32816       3           pyruvic acid   88.06206
# 55510    CHEBI:20067   CHEBI:20067       3  3-hydroxybutyric acid  104.10452
# 163345  CHEBI:116314  CHEBI:116314       3               oleamide  281.47660
# 90090    CHEBI:15891   CHEBI:15891       3                taurine  125.14800
# 5005     CHEBI:15741   CHEBI:15741       2          succinic acid  118.08800
# ...              ...           ...     ...                    ...        ...
# 83071    CHEBI:28300   CHEBI:27897       2              glutamine  146.14458
# 82922    CHEBI:28300   CHEBI:18237       2              glutamine  146.14458
# 82810    CHEBI:28300   CHEBI:28300       2              glutamine  146.14458
# 82757    CHEBI:28300   CHEBI:28044       2              glutamine  146.14458
# 203840   CHEBI:17634   CHEBI:17634       2              D-glucose  180.15588
#
# [383 rows x 5 columns]

# %%
edgelist_dmn[(edgelist_dmn['Name'] == 'tryptophan')]
# Out:
#              source       target  weight        Name       Mass
# 201251  CHEBI:27897  CHEBI:28044       2  tryptophan  204.22526
# 201304  CHEBI:27897  CHEBI:28300       2  tryptophan  204.22526
# 201416  CHEBI:27897  CHEBI:18237       2  tryptophan  204.22526
# 201565  CHEBI:27897  CHEBI:27897       2  tryptophan  204.22526

# %%
dmn_graph = nx.from_pandas_edgelist(edgelist_dmn, edge_attr='weight')
dmn_graph.remove_edges_from(nx.selfloop_edges(dmn_graph))
nx.set_node_attributes(dmn_graph, dict(dmn_graph.degree()), 'degree')

# %%
print(dmn_graph.number_of_nodes())
print(dmn_graph.number_of_edges())
# Out:
# 45
# 169

# %%
max(list(nx.get_node_attributes(dmn_graph, 'degree').values()))
# Out:
# 18

# %%
widths = nx.get_edge_attributes(dmn_graph, 'weight')
nodelist = dmn_graph.nodes()

plt.figure(figsize=(10,8))

pos = nx.kamada_kawai_layout(dmn_graph)
nds = nx.draw_networkx_nodes(dmn_graph,pos,
                       nodelist=nodelist,
                       node_size=20,
                       node_color=list(nx.get_node_attributes(dmn_graph, 'degree').values()),
                       cmap='Reds',
                       alpha=0.7)
nx.draw_networkx_edges(dmn_graph,pos,
                       edgelist = widths.keys(),
                       edge_color='lightblue',
                       alpha=0.6)

# Add a colorbar
cbar = plt.colorbar(nds, fraction=0.035, pad=0.04)
cbar.ax.set_ylabel('Degree', rotation=-90, va="bottom")

plt.box(False)
plt.margins(x=0.3)
plt.show()

# %% [markdown]
# Colour the nodes by
# - m/z ratio
#
# Label the nodes by
# - metabolite name

# %% [markdown]
# ## Connect to ChEBI API

# %%
libchebipy.ChebiEntity('CHEBI:1234').get_name()
# Out:
# '6-methoxy-2-octaprenyl-1,4-benzoquinone'

# %%
libchebipy.ChebiEntity('CHEBI:1234').get_mass()
# Out:
# 683.0569

# %%
# get names and mass of all compounds of interest
cpds_of_interest = list(set(edgelist_dmn['source'].tolist()))

# %%
chebi_names = {}
chebi_mass = {}
for c in cpds_of_interest:
    chebi_names[c] = libchebipy.ChebiEntity(c).get_name()
    chebi_mass[c] = libchebipy.ChebiEntity(c).get_mass()

# %%
edgelist_dmn['Name'] = edgelist_dmn['source'].map(chebi_names)
edgelist_dmn['Mass'] = edgelist_dmn['source'].map(chebi_mass)

# %%
edgelist_dmn
# Out:
#              source       target  weight           Name       Mass
# 5005    CHEBI:15741  CHEBI:15741       2  succinic acid  118.08800
# 5064    CHEBI:15741  CHEBI:17475       2  succinic acid  118.08800
# 5121    CHEBI:15741  CHEBI:17754       2  succinic acid  118.08800
# 5147    CHEBI:15741  CHEBI:37084       2  succinic acid  118.08800
# 5264    CHEBI:15741  CHEBI:75455       2  succinic acid  118.08800
# ...             ...          ...     ...            ...        ...
# 201416  CHEBI:27897  CHEBI:18237       2     tryptophan  204.22526
# 201565  CHEBI:27897  CHEBI:27897       2     tryptophan  204.22526
# 203514  CHEBI:17634  CHEBI:20067       2      D-glucose  180.15588
# 203628  CHEBI:17634  CHEBI:16977       2      D-glucose  180.15588
# 203840  CHEBI:17634  CHEBI:17634       2      D-glucose  180.15588
#
# [383 rows x 5 columns]

# %%
nx.set_node_attributes(dmn_graph, chebi_names, 'name')
nx.set_node_attributes(dmn_graph, chebi_mass, 'mass')

# %%
widths = nx.get_edge_attributes(dmn_graph, 'weight')
nodelist = dmn_graph.nodes()

plt.figure(figsize=(10,8))

pos = nx.kamada_kawai_layout(dmn_graph)
nds = nx.draw_networkx_nodes(dmn_graph,pos,
                       nodelist=nodelist,
                       node_size=list(nx.get_node_attributes(dmn_graph, 'degree').values()),
                       node_color=list(nx.get_node_attributes(dmn_graph, 'mass').values()),
                       cmap='Greens',
                       alpha=0.7)
nx.draw_networkx_edges(dmn_graph,pos,
                       edgelist = widths.keys(),
                       edge_color='lightblue',
                       alpha=0.6)
nx.draw_networkx_labels(dmn_graph, pos, labels=nx.get_node_attributes(dmn_graph, 'name'), font_size=8)

# Add a colorbar
cbar = plt.colorbar(nds, fraction=0.035, pad=0.04)
cbar.ax.set_ylabel('Degree', rotation=-90, va="bottom")

plt.box(False)
plt.margins(x=0.3)
plt.show()

# %%
nx.write_graphml(dmn_graph, 'covid_metabolites_network.graphml')
